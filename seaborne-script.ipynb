# %%
#first of all we need to import our libraries
import pandas as pd
import numpy as np

#if you didnot install from befor i will install seaborn now then you should use same code

# %%
# !pip install seaborn
# Out:
# ...
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      ---------------------------------------- 0.0/293.3 kB ? eta -:--:--
#      - -------------------------------------- 10.2/293.3 kB ? eta -:--:--
#      --- --------------------------------- 30.7/293.3 kB 330.3 kB/s eta 0:00:01
#      ----- ------------------------------- 41.0/293.3 kB 326.8 kB/s eta 0:00:01
#      --------- --------------------------- 71.7/293.3 kB 438.9 kB/s eta 0:00:01
#      ----------- ------------------------- 92.2/293.3 kB 476.3 kB/s eta 0:00:01
#      --------------- -------------------- 122.9/293.3 kB 481.4 kB/s eta 0:00:01
#      ------------------ ----------------- 153.6/293.3 kB 482.7 kB/s eta 0:00:01
#      ----------------------- ------------ 194.6/293.3 kB 562.0 kB/s eta 0:00:01
#      ------------------------- ---------- 204.8/293.3 kB 541.9 kB/s eta 0:00:01
#      ------------------------------ ----- 245.8/293.3 kB 538.9 kB/s eta 0:00:01
# ...

# %%
import seaborn as sns

# %%
# read salaries file called dataset
dataset= pd.read_csv(r"C:\Users\DC\Desktop\Salaries.csv")
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_13216\622152730.py:2: DtypeWarning: Columns (3,4,5,6,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset= pd.read_csv(r"C:\Users\DC\Desktop\Salaries.csv")

# %%
#check the head of your data 
dataset.head(5)
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay OvertimePay   OtherPay Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.0  400184.25      NaN  567595.43         567595.43
# 1  155966.02   245131.88  137811.38      NaN  538909.28         538909.28
# 2  212739.13   106088.18    16452.6      NaN  335279.91         335279.91
# 3    77916.0    56120.71   198306.9      NaN  332343.61         332343.61
# 4   134401.6      9737.0  182234.59      NaN  326373.19         326373.19
#
#    Year  Notes         Agency Status
# 0  2011    NaN  San Francisco    NaN
# ...

# %%
#Use the .info() method to find out how many entries there are
dataset.info() 
# its 148654entries
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148049 non-null  object
#  4   OvertimePay       148654 non-null  object
#  5   OtherPay          148654 non-null  object
#  6   Benefits          112495 non-null  object
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            38119 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 14.7+ MB

# %%
#how we can check the average TotalPay ?
dataset['TotalPay'].mean()
# Out:
# 74768.32197169267

# %%
#how we can check the highest amount of TotalPay in the dataset ?
dataset['TotalPay'].max()
# Out:
# 567595.43

# %%
#what is the job title of joesph driscoll

dataset[dataset['EmployeeName']=='JOSEPH DRISCOLL']['JobTitle']
# Out:
# 24    CAPTAIN, FIRE SUPPRESSION
# Name: JobTitle, dtype: object

# %%
#we can try to check how much does JOSEPH DRISCOLL make

dataset[dataset['EmployeeName']=='JOSEPH DRISCOLL']['TotalPayBenefits']
# Out:
# 24    270324.91
# Name: TotalPayBenefits, dtype: float64

# %%
# we can think also in what was the average (mean) TotalPay of all employees per year and we need to use groupby method

dataset.groupby('Year').mean()['TotalPay']
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_13216\1057825230.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   dataset.groupby('Year').mean()['TotalPay']
# Year
# 2011    71744.103871
# 2012    74113.262265
# 2013    77611.443142
# 2014    75463.918140
# Name: TotalPay, dtype: float64

# %%
#How many unique job titles we have do you know how to use unique method?

dataset['JobTitle'].nunique()
# Out:
# 2159

# %%
#What are the top 5 most common jobs?

dataset['JobTitle'].value_counts().head(5)
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
#lets to check How many people have the word Chief in their job title

def chief(string):
    if 'chief' in (string.lower()):
        return True
    else:
        return False

# %%
(dataset['JobTitle'].apply(lambda x: chief_string(x))).sum()

#can you find what is the wrong in ths code? how we can find out what we want here?^_*
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[41], line 1
# ----> 1 (dataset['JobTitle'].apply(lambda x: chief_string(x))).sum()
#       3 #can you find what is the wrong in ths code? how we can find out what we want here?
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\apply.py:1123, in SeriesApply.apply(self)
# ...

# %%
sns.distplot(dataset['TotalPay'])
# Out:
# C:\Users\DC\AppData\Local\Temp\ipykernel_13216\1381389889.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dataset['TotalPay'])
# <Axes: xlabel='TotalPay', ylabel='Density'>

# %%
sns.pairplot(dataset)
